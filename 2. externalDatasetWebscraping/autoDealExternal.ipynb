# %%
import pandas as pd

#Mount the google drive
from google.colab import drive
import os

drive.mount("/content/gdrive")
path = "/content/gdrive/MyDrive/[DATAPRE] Group 3 Submissions/Final Project"

os.chdir(path)
# Out:
# Mounted at /content/gdrive

# %%
primary = pd.read_csv("./datasets/autodeal.csv")
display(primary)
# Out:
#         Make     Model    Price  Vehicle      Fuel Transmission  Mileage  \
# 0     Suzuki  S-Presso   415000     2021  Gasoline       Manual   30,000
# 1       Ford   Everest   930000     2017    Diesel    Automatic   60,000
# 2      Honda     Civic   760000     2017  Gasoline    Automatic   50,000
# 3     Toyota    Innova  1120000     2023    Diesel    Automatic   17,000
# 4     Toyota     Camry   520000     2013  Gasoline    Automatic   60,000
# ..       ...       ...      ...      ...       ...          ...      ...
# 314   Suzuki    Ertiga   600000     2021  Gasoline       Manual    2,500
# 315      Kia  Sportage   950000     2017  Gasoline    Automatic   38,971
# 316  Hyundai    Accent   385000     2016    Diesel    Automatic  105,000
# 317    Mazda      CX-5   520000     2012  Gasoline    Automatic   48,000
# 318    Foton   Gratour   350000     2019  Gasoline       Manual   17,000
#
#      Engine       Body
# 0       1.0  Hatchback
# 1       2.2        SUV
# ...

# %%
uniqueMakes = primary['Make'].unique()
print(uniqueMakes)
i = 1
for make in uniqueMakes:
  print(f"{i}. {make}")
  i += 1
# Out:
# ['Suzuki' 'Ford' 'Honda' 'Toyota' 'Hyundai' 'Mitsubishi' 'Chevrolet'
#  'Nissan' 'Mazda' 'Geely' 'Kia' 'Isuzu' 'Subaru' 'BMW' 'Mercedes-Benz'
#  'MG' 'Jeep' 'Volkswagen' 'Audi' 'MINI' 'Land' 'Chery' 'Maxus' 'Lexus'
#  'Foton']
# 1. Suzuki
# 2. Ford
# 3. Honda
# 4. Toyota
# 5. Hyundai
# 6. Mitsubishi
# 7. Chevrolet
# 8. Nissan
# 9. Mazda
# 10. Geely
# 11. Kia
# 12. Isuzu
# 13. Subaru
# 14. BMW
# 15. Mercedes-Benz
# 16. MG
# 17. Jeep
# 18. Volkswagen
# 19. Audi
# 20. MINI
# 21. Land
# 22. Chery
# 23. Maxus
# 24. Lexus
# 25. Foton

# %%
# Webscraping of unique
import requests
import time
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
import numpy as np

# %%
# Webscraping
card_listings = []
for i in range(11, len(uniqueMakes)):
  print(uniqueMakes[i])

  parent_url = f"https://www.autodeal.com.ph/cars/{uniqueMakes[i]}"

  print(parent_url)

  parent_response = requests.get(parent_url)

  if parent_response.status_code == 200:
      parent_page_content = parent_response.text
  else:
      print("Failed to fetch the parent page. Status code:", parent_response.status_code)

  # Parse the parent page
  parent_soup = BeautifulSoup(parent_page_content, "html.parser")

  # Find all car cards
  car_cards = parent_soup.find_all("div", class_="card-car-model")
  display(len(car_cards))


  for car_card in car_cards:
    #keys and values
    car_card_url = "https://www.autodeal.com.ph%s" % (car_card.find("a")["href"])
    print(car_card_url)
    response = requests.get(car_card_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        page_content = response.text
    else:
        print("Failed to fetch the page. Status code:", response.status_code)

    soup = BeautifulSoup(page_content, "html.parser")

    # Columns for the Dataframe
    make_model_year = soup.find("h1", class_="bold nomargin padbottom5").text.split()
    make = make_model_year[0]
    model = make_model_year[1]
    year = make_model_year[-1]


    price = soup.find("span", class_="h2").text.split()
    print(price)
    if len(price) == 0:
      srp = np.nan
    else:
      srp = price[1].replace(",", "")
    print(srp)


    # display(make_model_year)

    keys = {"Make": np.nan, "Model": np.nan, "Year": np.nan, "SRP": np.nan}

    keys["Make"] = make
    keys["Model"] = model
    keys["Year"] = year
    keys["SRP"] = srp

    card_listings.append(keys)
    time.sleep(1)

print("Done!")
df = pd.DataFrame(card_listings)
display(df)
# Out:
# Isuzu
# https://www.autodeal.com.ph/cars/Isuzu
# 7
# https://www.autodeal.com.ph/cars/isuzu/c-series-378
# []
# nan
# https://www.autodeal.com.ph/cars/isuzu/d-max-2364
# ['Php', '938,000', '–', '1,945,000']
# 938000
# https://www.autodeal.com.ph/cars/isuzu/e-series
# []
# nan
# https://www.autodeal.com.ph/cars/isuzu/f-series
# ['Php', '1,570,000', '–', '4,150,000']
# 1570000
# https://www.autodeal.com.ph/cars/isuzu/mu-x
# ['Php', '1,675,000', '–', '2,580,000']
# 1675000
# https://www.autodeal.com.ph/cars/isuzu/n-series
# ['Php', '1,570,000', '–', '1,920,000']
# 1570000
# https://www.autodeal.com.ph/cars/isuzu/traviz
# ['Php', '1,005,000', '–', '1,300,000']
# 1005000
# Subaru
# https://www.autodeal.com.ph/cars/Subaru
# 7
# https://www.autodeal.com.ph/cars/subaru/brz
# ['Php', '2,549,000', '–', '2,704,000']
# 2549000
# https://www.autodeal.com.ph/cars/subaru/crosstrek
# ['Php', '1,998,000', '–', '2,088,000']
# 1998000
# https://www.autodeal.com.ph/cars/subaru/evoltis
# ...

# %%
suzuki_to_kia = pd.DataFrame(card_listings)
display(df)
# Out:
#        Make    Model  Year      SRP
# 0    Suzuki      APV  2024   743000
# 1    Suzuki    Carry  2024   614000
# 2    Suzuki  Celerio  2024   708000
# 3    Suzuki    Dzire  2024   609000
# 4    Suzuki   Ertiga  2024   954000
# ..      ...      ...   ...      ...
# 110     Kia    K2500  2024  1198000
# 111     Kia   Seltos  2024  1198000
# 112     Kia   Soluto  2024   780000
# 113     Kia    Sonet  2024   758000
# 114     Kia  Sorento  2024  2448000
#
# [115 rows x 4 columns]

# %%
isuzu_to_foton = pd.DataFrame(card_listings)
display(df)
# Out:
#       Make      Model  Year      SRP
# 0    Isuzu   C-Series  2024      NaN
# 1    Isuzu      D-MAX  2024   938000
# 2    Isuzu   E-Series  2024      NaN
# 3    Isuzu   F-Series  2024  1570000
# 4    Isuzu       mu-X  2024  1675000
# ..     ...        ...   ...      ...
# 103  Foton    Tornado  2024   915000
# 104  Foton   Transvan  2024  1290000
# 105  Foton  Traveller  2024  1330000
# 106  Foton    Tunland  2024  1758000
# 107  Foton    Tunland  2024  1788000
#
# [108 rows x 4 columns]

# %%
# Concatenate both dataframes
combined_df = pd.concat([suzuki_to_kia, isuzu_to_foton])
display(combined_df)
# Out:
#        Make      Model  Year      SRP
# 0    Suzuki        APV  2024   743000
# 1    Suzuki      Carry  2024   614000
# 2    Suzuki    Celerio  2024   708000
# 3    Suzuki      Dzire  2024   609000
# 4    Suzuki     Ertiga  2024   954000
# ..      ...        ...   ...      ...
# 103   Foton    Tornado  2024   915000
# 104   Foton   Transvan  2024  1290000
# 105   Foton  Traveller  2024  1330000
# 106   Foton    Tunland  2024  1758000
# 107   Foton    Tunland  2024  1788000
#
# [223 rows x 4 columns]

# %%
savepath = '/content/gdrive/MyDrive/[DATAPRE] Group 3 Submissions/Final Project/datasets/autodealExternal.csv'

combined_df.to_csv(savepath, index=False)
