# %%
import pandas as pd
#Mount the google drive
from google.colab import drive
import os

drive.mount("/content/gdrive")
path = "/content/gdrive/MyDrive/[DATAPRE] Group 3 Submissions/Final Project/datasets"

os.chdir(path)
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
primaryData = pd.read_csv("./transformedCleanedPrimaryData.csv")

display(primaryData)

externalData = pd.read_csv("./transformedCleanedExternalData.csv")

display(externalData)
# Out:
#              make     model  make_year fuel_type transmission  kms_driven  \
# 0          Suzuki  S-Presso       2021  Gasoline       Manual     30000.0
# 1            Ford   Everest       2017    Diesel    Automatic     60000.0
# 2           Honda     Civic       2017  Gasoline    Automatic     50000.0
# 3          Toyota    Innova       2023    Diesel    Automatic     17000.0
# 4          Toyota     Camry       2013  Gasoline    Automatic     60000.0
# ...           ...       ...        ...       ...          ...         ...
# 2216  Rolls-Royce     Ghost       2018  Gasoline    Automatic     20000.0
# 2217     Cadillac  Escalade       2022  Gasoline    Automatic        10.0
# 2218      Ferrari        F8       2024  Gasoline    Automatic     16000.0
# 2219      Bentley  Bentayga       2023  Gasoline    Automatic     30000.0
# 2220  Lamborghini      Urus       2023  Gasoline    Automatic      1300.0
#
#       engine_size  body_type  resale_price                key
# ...

# %%
# rename "make_year" as "ext_make_year"
externalData = externalData.rename(columns={"make_year": "ext_make_year"})

display(externalData)
# Out:
#        make      model  ext_make_year        srp              key
# 0    Suzuki        APV           2024   743000.0       Suzuki APV
# 1    Suzuki      Carry           2024   614000.0     Suzuki Carry
# 2    Suzuki    Celerio           2024   708000.0   Suzuki Celerio
# 3    Suzuki      Dzire           2024   609000.0     Suzuki Dzire
# 4    Suzuki     Ertiga           2024   954000.0    Suzuki Ertiga
# ..      ...        ...            ...        ...              ...
# 170   Foton  Toplander           2024  1488000.0  Foton Toplander
# 171   Foton    Tornado           2024   915000.0    Foton Tornado
# 172   Foton   Transvan           2024  1290000.0   Foton Transvan
# 173   Foton  Traveller           2024  1330000.0  Foton Traveller
# 174   Foton    Tunland           2024  1758000.0    Foton Tunland
#
# [175 rows x 5 columns]

# %%
# count the number of ext_make_year
externalData["ext_make_year"].value_counts()
# Out:
# ext_make_year
# 2024    175
# Name: count, dtype: int64

# %%
# Merge

mergedDataset = pd.merge(primaryData, externalData[["ext_make_year","srp", "key"]], on="key")
display(len(primaryData))
display(mergedDataset)
display(len(mergedDataset))
# Out:
# 2221
#            make     model  make_year fuel_type transmission  kms_driven  \
# 0        Suzuki  S-Presso       2021  Gasoline       Manual     30000.0
# 1        Suzuki  S-Presso       2021  Gasoline       Manual     35000.0
# 2        Suzuki  S-Presso       2021  Gasoline       Manual      9000.0
# 3        Suzuki  S-Presso       2022  Gasoline       Manual      6000.0
# 4        Suzuki  S-Presso       2023  Gasoline       Manual       800.0
# ...         ...       ...        ...       ...          ...         ...
# 1636  Chevrolet    Camaro       2019  Gasoline       Manual       900.0
# 1637    Hyundai  Palisade       2023    Diesel    Automatic     15000.0
# 1638        BMW         4       2020    Diesel    Automatic     16000.0
# 1639     Nissan      GT-R       2012  Gasoline    Automatic     16000.0
# 1640       Ford    Bronco       2022  Gasoline    Automatic       100.0
#
#       engine_size  body_type  resale_price               key  ext_make_year  \
# ...

# %%
# Rearrange the dataset in key, make, model, and so on

mergedDataset = mergedDataset[["key", "make", "model", "fuel_type",
                               "transmission", "body_type","make_year",
                               "ext_make_year", "kms_driven","engine_size",
                               "resale_price", "srp"]]

display(mergedDataset)
# Out:
#                    key       make     model fuel_type transmission  body_type  \
# 0      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 1      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 2      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 3      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 4      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# ...                ...        ...       ...       ...          ...        ...
# 1636  Chevrolet Camaro  Chevrolet    Camaro  Gasoline       Manual      Coupe
# 1637  Hyundai Palisade    Hyundai  Palisade    Diesel    Automatic        Suv
# 1638             BMW 4        BMW         4    Diesel    Automatic      Coupe
# 1639       Nissan GT-R     Nissan      GT-R  Gasoline    Automatic      Coupe
# 1640       Ford Bronco       Ford    Bronco  Gasoline    Automatic        Suv
#
# ...

# %%
# Check datatypes
mergedDataset.dtypes
# Out:
# key               object
# make              object
# model             object
# fuel_type         object
# transmission      object
# body_type         object
# make_year          int64
# ext_make_year      int64
# kms_driven       float64
# engine_size      float64
# resale_price     float64
# srp              float64
# dtype: object

# %%
# Check nulls
mergedDataset.isnull().sum()
# Out:
# key              0
# make             0
# model            0
# fuel_type        0
# transmission     0
# body_type        0
# make_year        0
# ext_make_year    0
# kms_driven       0
# engine_size      0
# resale_price     0
# srp              0
# dtype: int64

# %%
# Show duplicates of rows
mergedDataset[mergedDataset.duplicated()]

# I will not drop the merged dataset, why? Kase possible na may mga taong nagbebenta ng same car but different prices, kms_driven, engine size
# Out:
#                   key        make      model fuel_type transmission body_type  \
# 33       Ford Everest        Ford    Everest    Diesel    Automatic       Suv
# 34       Ford Everest        Ford    Everest    Diesel    Automatic       Suv
# 39       Ford Everest        Ford    Everest    Diesel       Manual       Suv
# 40       Ford Everest        Ford    Everest    Diesel    Automatic       Suv
# 41       Ford Everest        Ford    Everest    Diesel    Automatic       Suv
# ...               ...         ...        ...       ...          ...       ...
# 1480  Mitsubishi L300  Mitsubishi       L300    Diesel       Manual       Mpv
# 1513   Foton Transvan       Foton   Transvan    Diesel       Manual       Van
# 1515     Isuzu Traviz       Isuzu     Traviz    Diesel       Manual       Van
# 1527    Hyundai Santa     Hyundai      Santa    Diesel    Automatic       Suv
# 1553  Foton Traveller       Foton  Traveller    Diesel       Manual       Van
#
# ...

# %%
display(mergedDataset)
# Out:
#                    key       make     model fuel_type transmission  body_type  \
# 0      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 1      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 2      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 3      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 4      Suzuki S-Presso     Suzuki  S-Presso  Gasoline       Manual  Hatchback
# ...                ...        ...       ...       ...          ...        ...
# 1636  Chevrolet Camaro  Chevrolet    Camaro  Gasoline       Manual      Coupe
# 1637  Hyundai Palisade    Hyundai  Palisade    Diesel    Automatic        Suv
# 1638             BMW 4        BMW         4    Diesel    Automatic      Coupe
# 1639       Nissan GT-R     Nissan      GT-R  Gasoline    Automatic      Coupe
# 1640       Ford Bronco       Ford    Bronco  Gasoline    Automatic        Suv
#
# ...

# %% [markdown]
# # Another External Dataset

# %%
# Show unique makes
uniqueMakes = mergedDataset["make"].unique()
i = 1
for make in uniqueMakes:
  print(f"{i}. {make}")
  i+=1
# Out:
# 1. Suzuki
# 2. Ford
# 3. Honda
# 4. Toyota
# 5. Hyundai
# 6. Mitsubishi
# 7. Mazda
# 8. Geely
# 9. Nissan
# 10. Chevrolet
# 11. Isuzu
# 12. Subaru
# 13. BMW
# 14. Mercedes-Benz
# 15. Kia
# 16. MG
# 17. MINI
# 18. Chery
# 19. Lexus
# 20. Foton
# 21. Volkswagen
# 22. Audi
# 23. Jeep

# %%
# Second external dataset (this dataset was inputted manually)
externalDataset2 = pd.read_csv("./make_mshops.csv")
display(externalDataset2)
# Out:
#              make  no_sc_mmnl
# 0          Suzuki           9
# 1            Ford           2
# 2           Honda           4
# 3          Toyota           9
# 4         Hyundai           6
# 5      Mitsubishi           4
# 6           Mazda           1
# 7           Geely           4
# 8          Nissan           2
# 9       Chevrolet           4
# 10          Isuzu           6
# 11         Subaru           6
# 12            BMW           4
# 13  Mercedes-Benz           1
# 14            Kia           6
# 15             MG           4
# 16           MINI           1
# 17          Chery           2
# 18          Lexus           1
# 19          Foton           0
# 20     Volkswagen           0
# 21           Audi           1
# 22           Jeep           0

# %%
# Compare
for i in range(len(uniqueMakes)):
  if uniqueMakes[i] == externalDataset2["make"][i]:
    print("True")
  else:
    print(uniqueMakes[i])
    print(externalDataset2["make"][i])
    print("False")
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %%
display(externalDataset2.dtypes)
# Out:
# make          object
# no_sc_mmnl     int64
# dtype: object

# %%
mergedDataset2 = pd.merge(mergedDataset, externalDataset2[["make", "no_sc_mmnl"]], on="make")

display(mergedDataset2)
display(len(mergedDataset))
# Out:
#                   key    make     model fuel_type transmission  body_type  \
# 0     Suzuki S-Presso  Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 1     Suzuki S-Presso  Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 2     Suzuki S-Presso  Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 3     Suzuki S-Presso  Suzuki  S-Presso  Gasoline       Manual  Hatchback
# 4     Suzuki S-Presso  Suzuki  S-Presso  Gasoline       Manual  Hatchback
# ...               ...     ...       ...       ...          ...        ...
# 1636       Jeep Grand    Jeep     Grand    Diesel    Automatic        Suv
# 1637       Jeep Grand    Jeep     Grand  Gasoline    Automatic        Suv
# 1638       Jeep Grand    Jeep     Grand  Gasoline    Automatic        Suv
# 1639       Jeep Grand    Jeep     Grand  Gasoline    Automatic        Suv
# 1640    Jeep Wrangler    Jeep  Wrangler  Gasoline    Automatic        Suv
#
#       make_year  ext_make_year  kms_driven  engine_size  resale_price  \
# ...

# %%
savepath1 = "./mergedDataset.csv"

mergedDataset2.to_csv(savepath1, index = False)
